# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as stats

# %%
data = np.array([-123,6, 7, 7, 12, 13, 13, 15, 16, 19, 22,150])

# %%
import seaborn as sns
sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
a=stats.zscore(data)

# %%
a
# Out:
# array([-2.43378378e+00, -1.26681948e-01, -1.08797438e-01, -1.08797438e-01,
#        -1.93748862e-02, -1.49037586e-03, -1.49037586e-03,  3.42786448e-02,
#         5.21631551e-02,  1.05816686e-01,  1.59470217e-01,  2.44868754e+00])

# %%
sns.histplot(a)
# Out:
# <Axes: ylabel='Count'>

# %%
a
# Out:
# array([-2.43378378e+00, -1.26681948e-01, -1.08797438e-01, -1.08797438e-01,
#        -1.93748862e-02, -1.49037586e-03, -1.49037586e-03,  3.42786448e-02,
#         5.21631551e-02,  1.05816686e-01,  1.59470217e-01,  2.44868754e+00])

# %%
#sns.histplot(a)
o=[]
for i in d1:
  if i>3:
    o.append(i)
print(o)
# Out:
# [4.250856442260368, 3.316174311117456]

# %%
x=[]
for i in d1:
  if i not in o:
    x.append(i)
x
# Out:
# [-0.11099350307322078,
#  0.20056720730774982,
#  0.294035420422041,
#  -0.048681360997026656,
#  -0.3290860003399002,
#  -0.36024207137799724,
#  -0.2979299293018031,
#  -0.3290860003399002,
#  -0.36024207137799724,
#  -0.3290860003399002,
#  -0.36024207137799724,
#  -0.3290860003399002,
#  -0.36024207137799724,
#  -0.3290860003399002,
#  -0.36024207137799724,
#  0.294035420422041,
#  -0.2667738582637061,
#  -0.36024207137799724,
#  -0.3290860003399002,
#  -0.36024207137799724,
#  -0.3290860003399002,
#  -0.3290860003399002,
#  -0.3290860003399002,
#  -0.2979299293018031,
#  -0.2667738582637061,
#  -0.3290860003399002,
#  -0.2979299293018031,
#  -0.3290860003399002,
#  -0.2979299293018031,
#  -0.3290860003399002]

# %%
sns.histplot(x)
# Out:
# <Axes: ylabel='Count'>

# %%
d=[10,20,23,12,3,2,4,3,2,3,2,150,3,2,3,2,23,5,2,3,2,3,3,3,4,5,3,4,3,4,3,120]
plt.hist(d)
d1=stats.zscore(d)

# %%
sns.histplot(d1)
# Out:
# <Axes: ylabel='Count'>

# %%
data = np.random.normal(0, 1, 100)

# %%
plt.hist(z_scores,kde=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-d3f528f24cd0> in <cell line: 1>()
# ----> 1 plt.hist(z_scores,kde=True)
#       2 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
#    2646         x, bins=bins, range=range, density=density, weights=weights,
#    2647         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
data = np.random.normal(0, 1, 100)
z_scores = (data - np.mean(data)) / np.std(data)
from scipy import stats

z_scores = stats.zscore(data)
print(z_scores)
# Out:
# [ 0.53072419  0.72086037 -1.58610142 -0.35201062  0.63366485 -0.20298362
#  -1.99000886  0.97427054 -0.16438748  0.18281322 -0.43532133 -1.8658502
#  -0.78266519 -0.35918265 -0.13494642  0.30438248  0.48605741  0.41918491
#   1.69623204 -0.74824585 -1.9393041   0.31668998  1.0062125  -1.48991956
#   0.09202019  1.42658414 -0.25776595 -0.33279865 -0.05053063  0.06030254
#   0.33410804  1.29514161  0.56715783  0.19360178  0.38839575 -0.8518051
#   0.41641093  0.46323725  0.62669281  0.37928609 -2.49501699  0.25771314
#   1.21978986  1.39238636  0.60109821 -0.21350877 -0.65042903 -0.11066625
#   2.57516526  0.56579107  1.42043882  0.07568176 -0.18628135 -0.54396547
#  -0.91905616  1.9594465   1.15742879  0.7666332  -0.91052904  0.22881698
#  -0.58393399  0.36062273  0.83032364  0.19635177 -0.4715076  -1.3049632
#   1.28705517 -0.90305929 -0.83619465  1.22211545 -0.69631089 -1.68628959
#   0.61953059  1.53895526  0.87358829  0.33896989 -1.34270524 -0.04680259
# ...

# %%
#Z score
def detect_outlier(a):
  outlier=[]
  threshold=3  ## should be away from 3rd s.d.
  mean=np.mean(data)
  sd=np.std(data)
  for i in data:
    z_score=(i-mean)/sd
    if np.abs(z_score)>threshold:
      outlier.append(i)
  return outlier

# %%
detect_outlier([-12300,6, 7, 7, 12, 13, 13, 15, 16, 19, 22,15000])
# Out:
# []

# %%
data = np.array([[5, 6, 7, 7, 8],
                 [8, 8, 8, 9, 9],
                 [2, 2, 4, 4, 5]])

# %%
stats.zscore(data, axis=1)

# %% [markdown]
# IQR
# 1.sort data
# 2.calculate Q1 (25%) and Q3(75%)
# 3.IQR(Q3-Q1)
# 4.Find lower fence(q1-1.5(iqr))
# 5.Find the higherfence(q3+1.5(iqr))

# %%
##sort
data=sorted(d)

# %%
[q1,q3]=np.percentile(data,[25,75])
print(q1,q3)

# %%
iqr=q3-q1
print(iqr)

# %%
#lower fence
lf=q1-(1.5*iqr)
hf=q3+(1.5*iqr)
print(lf,hf)

# %%
import seaborn as sns
sns.boxplot(d)
