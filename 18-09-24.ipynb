# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import seaborn as sns
df=sns.load_dataset('tips')

# %%
sns.boxplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
percentile75=df['total_bill'].quantile(0.75)
percentile25=df['total_bill'].quantile(0.25)
iqr=percentile75-percentile25
print('iqr:',iqr)
print(percentile25)
print(percentile75)
upper_limit=percentile75+1.5*(iqr)
lower_limit=percentile25-1.5*(iqr)
print(upper_limit)
print(lower_limit)
# Out:
# iqr: 10.779999999999998
# 13.3475
# 24.127499999999998
# 40.29749999999999
# -2.8224999999999945

# %%
sns.distplot(df['total_bill'])
# Out:
# <ipython-input-14-08d2c75decc2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(new_df['total_bill'])
# Out:
# <ipython-input-15-08ce69af3fa1>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.boxplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot(df['total_bill'])
plt.subplot(2,2,2)
sns.boxplot(df['total_bill'])
plt.subplot(2,2,3)
sns.distplot(df['tip'])
plt.subplot(2,2,4)
sns.boxplot(df['tip'])
plt.show()
# Out:
# <ipython-input-13-01608cd80a50>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'])
# <ipython-input-13-01608cd80a50>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tip'])

# %%
#18-09-24
