# %%
i=1
while i<4:
  a=int(input("enter a number:\t"))
  if a<=10 and a>0:
    print("welcome")
    break
  else:
    print("try again")
    i=i+1
  if i==4:
    print("invalid number")
# Out:
# enter a number:	33
# try again
# enter a number:	3
# welcome
