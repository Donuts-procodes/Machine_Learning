# %%
def credit():
  ask=input("do you want to use your credit card?yes or no:\t")
  if ask=="yes":
    x=int(input("enter your amount:\t"))
    return x,ask
  else:
    print("thank you")
    return 0,ask

# %%
def decor(f):
  def inner():
    x,ask=f()
    amt=0
    if ask=='yes':
      amt=x+(x*0.1)
      print(f"your total amopunt is {amt}")
    else:
      print("thank you")
  return inner
@decor
def payment():
  return credit()
payment()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-240c45fac807> in <cell line: 14>()
#      12 def payment():
#      13   return credit()
# ---> 14 payment()
#
# <ipython-input-9-240c45fac807> in inner()
#       1 def decor(f):
#       2   def inner():
# ----> 3     x,ask=f()
#       4     amt=0
#       5     if ask=='yes':
#
# TypeError: cannot unpack non-iterable int object

# %%
def hobby():
  a=[]
  ask=input("do you want to add your hobby?yes or no:\t")
  if ask=='yes':
    return True
  else:
    return
# Out:
# do you want to add your hobby?yes or no:	yes
# enter your hobby:	coding
# (['coding'], 'yes')
