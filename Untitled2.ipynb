# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('/train.csv',encoding='latin-1')

# %%
df.shape
# Out:
# (550068, 12)

# %%
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00370293',
#        'P00371644', 'P00370853'], dtype=object)

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# Male                               0
# dtype: int64

# %%
df['Product_ID']=df['Product_ID'].astype(int)

# %%
df['Product_ID'].dtype
# Out:
# dtype('int64')

# %%
df['Occupation'].dtype
# Out:
# dtype('int64')

# %%
df[['Male']]=pd.get_dummies(df['Gender'],drop_first=True).astype(int)

# %%
df=df.drop('Gender',axis=1)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Purchase'].query('Male==1')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-ec99011e5969> in <cell line: 1>()
# ----> 1 df['Purchase'].query('Male==1')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'query'

# %%
female_df = df[df['Male'] == 1]['Purchase']

# %%
male_df = df[df['Male'] == 0]['Purchase']

# %%
gender_purchase_data = pd.DataFrame({
    'Gender': ['Male', 'Female'],
    'Total Purchase': [male_purchase_total, female_purchase_total]
})

# Plot the bar chart
sns.barplot(x='Gender', y='Total Purchase', data=gender_purchase_data)

# Add title and labels
plt.title('Total Purchases by Gender')
plt.ylabel('Total Purchase Amount')
plt.xlabel('Gender')

# Show the plot
plt.show()
